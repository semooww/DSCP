# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization
from keras.models import Sequential
from keras.utils import to_categorical
from keras.callbacks import LearningRateScheduler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
import cv2
import os
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
DATASET_PATH = r"./dataset/"
IMAGE_WIDTH = 256
IMAGE_HEIGHT = 256
EPOCHS = 30
BATCH_SIZE = 32
SEED = 42
dataset_folders = []
total = 0
print(f"There are {len(os.listdir(DATASET_PATH))} folder in dataset.")
for path in sorted(os.listdir(DATASET_PATH)):
    print(f"\t-There are {len(os.listdir(DATASET_PATH + path))} images in {path} folder.")
    total += len(os.listdir(DATASET_PATH + path))
    folder_path = DATASET_PATH + path
    dataset_folders.append(folder_path)

df = pd.DataFrame(0,
                  columns=['paths',
                           'class-label'],
                  index=range(total))
i = 0
for p, path in enumerate(dataset_folders):
    for sub_path in sorted(os.listdir(path)):
        df.iloc[i, 0] = path + "/" + sub_path
        df.iloc[i, 1] = p
        i += 1
print(df.sample(frac=1, random_state=SEED).head(10))

# %%
#normalizes the histogram of images
def normalize_histograms(img):
    image_copy = img.copy()
    for i in range(3):
        imi = img[:, :, i]
        minval = np.min(imi)
        maxval = np.max(imi)
        imrange = maxval - minval
        # imi-minval will turn the color range between 0-imrange, and the scaling will stretch the range between 0-255
        image_copy[:, :, i] = (255 / (imrange + 0.0001) * (imi - minval))
    return image_copy


#Cropping image to avoid from unuseful black areas
def deleteBlackAreas(filename):
    image_size = (IMAGE_WIDTH, IMAGE_HEIGHT)
    img = cv2.imread(filename)  #read image from file
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert to grayscale
    _, thresh = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)  # turn it into a binary image
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)  # find contours
    if len(contours) != 0:
        #find the biggest area
        cnt = max(contours, key=cv2.contourArea)

        #find the bounding rect
        x, y, w, h = cv2.boundingRect(cnt)

        crop = img[y:y + h, x:x + w]  # crop image
        crop1 = cv2.cvtColor(cv2.resize(crop, image_size, interpolation=cv2.INTER_AREA),
                             cv2.COLOR_BGR2RGB)  # resize to image_size and change color space from BGR to RGB for matplotlib
        return crop1
    else:
        return cv2.resize(img, image_size, interpolation=cv2.INTER_AREA)

# %%
def create_dataset(df, mode=0):
    # Creating dataset
    images = []
    labels = []
    # df = df.sample(frac=1, random_state=SEED)
    for i in range(len(df)):
        filename = df.iloc[i]["paths"]
        print(f"{i}. step---> {filename}")
        img = deleteBlackAreas(filename)
        if mode == 1:
            img = normalize_histograms(img)
        label = df.iloc[i]["class-label"]

        imlr= cv2.flip(img,0)
        imud= cv2.flip(img,1)

        #add all the images an labels
        images.append(img)
        labels.append(label)
        images.append(imlr)
        labels.append(label)
        images.append(imud)
        labels.append(label)

        # imb=img+0.05*img # brighter image
        # imblr=cv2.flip(imb,0)
        # imbud=cv2.flip(imb,1)
        # images.append(imb)
        # labels.append(label)
        # images.append(imblr)
        # labels.append(label)
        # images.append(imbud)
        # labels.append(label)

        imd=img-0.075*img #deemer image
        imdlr=cv2.flip(imd,0)
        imdud=cv2.flip(imd,1)
        images.append(imd)
        labels.append(label)
        images.append(imdlr)
        labels.append(label)
        images.append(imdud)
        labels.append(label)
    print(f"{len(images)} images in images array and {len(labels)} labels in labels array")
    return np.array(images), np.array(labels)


def split_dataset(X, Y):
    # set aside 20% of train and test data for evaluation
    X_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, shuffle=True, random_state=SEED)
    # Use the same function above for the validation set
    X_train = np.array(X_train)
    x_val = np.array(x_val)
    y_train = np.array(y_train)
    y_val = np.array(y_val)
    print("X_train shape: {}".format(X_train.shape))
    print("x_val shape: {}".format(x_val.shape))
    print("y_train shape: {}".format(y_train.reshape(-1, 1).shape))
    print("y_val shape: {}".format(y_val.reshape(-1, 1).shape))
    return [X_train, x_val, y_train, y_val]

# %%
X, y = create_dataset(df)
# Out:
# 0. step---> ./dataset/1_normal/NL_001.png
# 1. step---> ./dataset/1_normal/NL_002.png
# 2. step---> ./dataset/1_normal/NL_003.png
# 3. step---> ./dataset/1_normal/NL_004.png
# 4. step---> ./dataset/1_normal/NL_005.png
# 5. step---> ./dataset/1_normal/NL_006.png
# 6. step---> ./dataset/1_normal/NL_007.png
# 7. step---> ./dataset/1_normal/NL_008.png
# 8. step---> ./dataset/1_normal/NL_009.png
# 9. step---> ./dataset/1_normal/NL_010.png
# 10. step---> ./dataset/1_normal/NL_011.png
# 11. step---> ./dataset/1_normal/NL_012.png
# 12. step---> ./dataset/1_normal/NL_013.png
# 13. step---> ./dataset/1_normal/NL_014.png
# 14. step---> ./dataset/1_normal/NL_015.png
# 15. step---> ./dataset/1_normal/NL_016.png
# 16. step---> ./dataset/1_normal/NL_017.png
# 17. step---> ./dataset/1_normal/NL_018.png
# 18. step---> ./dataset/1_normal/NL_019.png
# 19. step---> ./dataset/1_normal/NL_020.png
# 20. step---> ./dataset/1_normal/NL_021.png
# 21. step---> ./dataset/1_normal/NL_022.png
# 22. step---> ./dataset/1_normal/NL_023.png
# 23. step---> ./dataset/1_normal/NL_024.png
# 24. step---> ./dataset/1_normal/NL_025.png
# 25. step---> ./dataset/1_normal/NL_026.png
# 26. step---> ./dataset/1_normal/NL_027.png
# 27. step---> ./dataset/1_normal/NL_028.png
# 28. step---> ./dataset/1_normal/NL_029.png
# 29. step---> ./dataset/1_normal/NL_030.png
# 30. step---> ./dataset/1_normal/NL_031.png
# 31. step---> ./dataset/1_normal/NL_032.png
# 32. step---> ./dataset/1_normal/NL_033.png
# 33. step---> ./dataset/1_normal/NL_034.png
# 34. step---> ./dataset/1_normal/NL_035.png
# 35. step---> ./dataset/1_normal/NL_036.png
# 36. step---> ./dataset/1_normal/NL_037.png
# 37. step---> ./dataset/1_normal/NL_038.png
# 38. step---> ./dataset/1_normal/NL_039.png
# 39. step---> ./dataset/1_normal/NL_040.png
# 389. step---> ./dataset/2_cataract/cataract_090.png
# 390. step---> ./dataset/2_cataract/cataract_091.png
# 391. step---> ./dataset/2_cataract/cataract_092.png
# 392. step---> ./dataset/2_cataract/cataract_093.png
# 393. step---> ./dataset/2_cataract/cataract_094.png
# 394. step---> ./dataset/2_cataract/cataract_095.png
# 395. step---> ./dataset/2_cataract/cataract_096.png
# 396. step---> ./dataset/2_cataract/cataract_097.png
# 397. step---> ./dataset/2_cataract/cataract_098.png
# 398. step---> ./dataset/2_cataract/cataract_099.png
# 399. step---> ./dataset/2_cataract/cataract_100.png
# 400. step---> ./dataset/2_glaucoma/Glaucoma_001.png
# 401. step---> ./dataset/2_glaucoma/Glaucoma_002.png
# 402. step---> ./dataset/2_glaucoma/Glaucoma_003.png
# 403. step---> ./dataset/2_glaucoma/Glaucoma_004.png
# 404. step---> ./dataset/2_glaucoma/Glaucoma_005.png
# 405. step---> ./dataset/2_glaucoma/Glaucoma_006.png
# 406. step---> ./dataset/2_glaucoma/Glaucoma_007.png
# 407. step---> ./dataset/2_glaucoma/Glaucoma_008.png
# 408. step---> ./dataset/2_glaucoma/Glaucoma_009.png
# 409. step---> ./dataset/2_glaucoma/Glaucoma_010.png
# 410. step---> ./dataset/2_glaucoma/Glaucoma_011.png
# 411. step---> ./dataset/2_glaucoma/Glaucoma_012.png
# 412. step---> ./dataset/2_glaucoma/Glaucoma_013.png
# 413. step---> ./dataset/2_glaucoma/Glaucoma_014.png
# 414. step---> ./dataset/2_glaucoma/Glaucoma_015.png
# 415. step---> ./dataset/2_glaucoma/Glaucoma_016.png
# 416. step---> ./dataset/2_glaucoma/Glaucoma_017.png
# 417. step---> ./dataset/2_glaucoma/Glaucoma_018.png
# 418. step---> ./dataset/2_glaucoma/Glaucoma_019.png
# 419. step---> ./dataset/2_glaucoma/Glaucoma_020.png
# 420. step---> ./dataset/2_glaucoma/Glaucoma_021.png
# 421. step---> ./dataset/2_glaucoma/Glaucoma_022.png
# 422. step---> ./dataset/2_glaucoma/Glaucoma_023.png
# 423. step---> ./dataset/2_glaucoma/Glaucoma_024.png
# 424. step---> ./dataset/2_glaucoma/Glaucoma_025.png
# 425. step---> ./dataset/2_glaucoma/Glaucoma_026.png
# 426. step---> ./dataset/2_glaucoma/Glaucoma_027.png
# 427. step---> ./dataset/2_glaucoma/Glaucoma_028.png
# 428. step---> ./dataset/2_glaucoma/Glaucoma_029.png
# 429. step---> ./dataset/2_glaucoma/Glaucoma_030.png
# 430. step---> ./dataset/2_glaucoma/Glaucoma_031.png
# 431. step---> ./dataset/2_glaucoma/Glaucoma_032.png
# 432. step---> ./dataset/2_glaucoma/Glaucoma_033.png
# 433. step---> ./dataset/2_glaucoma/Glaucoma_034.png
# 434. step---> ./dataset/2_glaucoma/Glaucoma_035.png
# 435. step---> ./dataset/2_glaucoma/Glaucoma_036.png
# 436. step---> ./dataset/2_glaucoma/Glaucoma_037.png
# 437. step---> ./dataset/2_glaucoma/Glaucoma_038.png
# 438. step---> ./dataset/2_glaucoma/Glaucoma_039.png
# 439. step---> ./dataset/2_glaucoma/Glaucoma_040.png
# 440. step---> ./dataset/2_glaucoma/Glaucoma_041.png
# 441. step---> ./dataset/2_glaucoma/Glaucoma_042.png
# 442. step---> ./dataset/2_glaucoma/Glaucoma_043.png
# 443. step---> ./dataset/2_glaucoma/Glaucoma_044.png
# 444. step---> ./dataset/2_glaucoma/Glaucoma_045.png
# 445. step---> ./dataset/2_glaucoma/Glaucoma_046.png
# 446. step---> ./dataset/2_glaucoma/Glaucoma_047.png
# 447. step---> ./dataset/2_glaucoma/Glaucoma_048.png
# 448. step---> ./dataset/2_glaucoma/Glaucoma_049.png
# 449. step---> ./dataset/2_glaucoma/Glaucoma_050.png
# 450. step---> ./dataset/2_glaucoma/Glaucoma_051.png
# 451. step---> ./dataset/2_glaucoma/Glaucoma_052.png
# 452. step---> ./dataset/2_glaucoma/Glaucoma_053.png
# 453. step---> ./dataset/2_glaucoma/Glaucoma_054.png
# 454. step---> ./dataset/2_glaucoma/Glaucoma_055.png
# 455. step---> ./dataset/2_glaucoma/Glaucoma_056.png
# 456. step---> ./dataset/2_glaucoma/Glaucoma_057.png
# 457. step---> ./dataset/2_glaucoma/Glaucoma_058.png
# 458. step---> ./dataset/2_glaucoma/Glaucoma_059.png
# 459. step---> ./dataset/2_glaucoma/Glaucoma_060.png
# 460. step---> ./dataset/2_glaucoma/Glaucoma_061.png
# 461. step---> ./dataset/2_glaucoma/Glaucoma_062.png
# 462. step---> ./dataset/2_glaucoma/Glaucoma_063.png
# 463. step---> ./dataset/2_glaucoma/Glaucoma_064.png
# 464. step---> ./dataset/2_glaucoma/Glaucoma_065.png
# 465. step---> ./dataset/2_glaucoma/Glaucoma_066.png
# 466. step---> ./dataset/2_glaucoma/Glaucoma_067.png
# 467. step---> ./dataset/2_glaucoma/Glaucoma_068.png
# 468. step---> ./dataset/2_glaucoma/Glaucoma_069.png
# 469. step---> ./dataset/2_glaucoma/Glaucoma_070.png
# 470. step---> ./dataset/2_glaucoma/Glaucoma_071.png
# 471. step---> ./dataset/2_glaucoma/Glaucoma_072.png
# 472. step---> ./dataset/2_glaucoma/Glaucoma_073.png
# 473. step---> ./dataset/2_glaucoma/Glaucoma_074.png
# 474. step---> ./dataset/2_glaucoma/Glaucoma_075.png
# 475. step---> ./dataset/2_glaucoma/Glaucoma_076.png
# 476. step---> ./dataset/2_glaucoma/Glaucoma_077.png
# 477. step---> ./dataset/2_glaucoma/Glaucoma_078.png
# 478. step---> ./dataset/2_glaucoma/Glaucoma_079.png
# 479. step---> ./dataset/2_glaucoma/Glaucoma_080.png
# 480. step---> ./dataset/2_glaucoma/Glaucoma_081.png
# 481. step---> ./dataset/2_glaucoma/Glaucoma_082.png
# 482. step---> ./dataset/2_glaucoma/Glaucoma_083.png
# 483. step---> ./dataset/2_glaucoma/Glaucoma_084.png
# 484. step---> ./dataset/2_glaucoma/Glaucoma_085.png
# 485. step---> ./dataset/2_glaucoma/Glaucoma_086.png
# 486. step---> ./dataset/2_glaucoma/Glaucoma_087.png
# 487. step---> ./dataset/2_glaucoma/Glaucoma_088.png
# 488. step---> ./dataset/2_glaucoma/Glaucoma_089.png
# 489. step---> ./dataset/2_glaucoma/Glaucoma_090.png
# 490. step---> ./dataset/2_glaucoma/Glaucoma_091.png
# 491. step---> ./dataset/2_glaucoma/Glaucoma_092.png
# 492. step---> ./dataset/2_glaucoma/Glaucoma_093.png
# 493. step---> ./dataset/2_glaucoma/Glaucoma_094.png
# 494. step---> ./dataset/2_glaucoma/Glaucoma_095.png
# 495. step---> ./dataset/2_glaucoma/Glaucoma_096.png
# 496. step---> ./dataset/2_glaucoma/Glaucoma_097.png
# 497. step---> ./dataset/2_glaucoma/Glaucoma_098.png
# 498. step---> ./dataset/2_glaucoma/Glaucoma_099.png
# 499. step---> ./dataset/2_glaucoma/Glaucoma_100.png
# 500. step---> ./dataset/2_glaucoma/Glaucoma_101.png
# 501. step---> ./dataset/3_retina_disease/Retina_001.png
# 502. step---> ./dataset/3_retina_disease/Retina_002.png
# 503. step---> ./dataset/3_retina_disease/Retina_003.png
# 504. step---> ./dataset/3_retina_disease/Retina_004.png
# 505. step---> ./dataset/3_retina_disease/Retina_005.png
# 506. step---> ./dataset/3_retina_disease/Retina_006.png
# 507. step---> ./dataset/3_retina_disease/Retina_007.png
# 508. step---> ./dataset/3_retina_disease/Retina_008.png
# 509. step---> ./dataset/3_retina_disease/Retina_009.png
# 510. step---> ./dataset/3_retina_disease/Retina_010.png
# 511. step---> ./dataset/3_retina_disease/Retina_011.png
# 512. step---> ./dataset/3_retina_disease/Retina_012.png
# 513. step---> ./dataset/3_retina_disease/Retina_013.png
# 514. step---> ./dataset/3_retina_disease/Retina_014.png
# 515. step---> ./dataset/3_retina_disease/Retina_015.png
# 516. step---> ./dataset/3_retina_disease/Retina_016.png
# 517. step---> ./dataset/3_retina_disease/Retina_017.png
# 518. step---> ./dataset/3_retina_disease/Retina_018.png
# 519. step---> ./dataset/3_retina_disease/Retina_019.png
# 520. step---> ./dataset/3_retina_disease/Retina_020.png
# 521. step---> ./dataset/3_retina_disease/Retina_021.png
# 522. step---> ./dataset/3_retina_disease/Retina_022.png
# 523. step---> ./dataset/3_retina_disease/Retina_023.png
# 524. step---> ./dataset/3_retina_disease/Retina_024.png
# 525. step---> ./dataset/3_retina_disease/Retina_025.png
# 526. step---> ./dataset/3_retina_disease/Retina_026.png
# 527. step---> ./dataset/3_retina_disease/Retina_027.png
# 528. step---> ./dataset/3_retina_disease/Retina_028.png
# 529. step---> ./dataset/3_retina_disease/Retina_029.png
# 530. step---> ./dataset/3_retina_disease/Retina_030.png
# 531. step---> ./dataset/3_retina_disease/Retina_031.png
# 583. step---> ./dataset/3_retina_disease/Retina_083.png
# 584. step---> ./dataset/3_retina_disease/Retina_084.png
# 585. step---> ./dataset/3_retina_disease/Retina_085.png
# 586. step---> ./dataset/3_retina_disease/Retina_086.png
# 587. step---> ./dataset/3_retina_disease/Retina_087.png
# 588. step---> ./dataset/3_retina_disease/Retina_088.png
# 589. step---> ./dataset/3_retina_disease/Retina_089.png
# 590. step---> ./dataset/3_retina_disease/Retina_090.png
# 591. step---> ./dataset/3_retina_disease/Retina_091.png
# 592. step---> ./dataset/3_retina_disease/Retina_092.png
# 593. step---> ./dataset/3_retina_disease/Retina_093.png
# 594. step---> ./dataset/3_retina_disease/Retina_094.png
# 595. step---> ./dataset/3_retina_disease/Retina_095.png
# 596. step---> ./dataset/3_retina_disease/Retina_096.png
# 597. step---> ./dataset/3_retina_disease/Retina_097.png
# 598. step---> ./dataset/3_retina_disease/Retina_098.png
# 599. step---> ./dataset/3_retina_disease/Retina_099.png
# 600. step---> ./dataset/3_retina_disease/Retina_100.png
# 3606 images in images array and 3606 labels in labels array

# %%
[X_train, x_val, y_train, y_val] = split_dataset(X, y)

# %%
def plot_pie_sets(arrays):
    titles = ["Train Set", "Validation Set"]
    labels = ["Normal", "Cataract", "Glaucoma", "Retina Disease"]
    fig = plt.figure(figsize=(9, 5))
    plt.title("Distribution")
    plt.axis('off')
    plt.grid(False)
    for i in range(2):
        fig.add_subplot(1, 2, i + 1)
        arr = []
        for j in range(4):
            arr.append((arrays[i] == j).sum())
        labels = ["Normal", "Cataract", "Glaucoma", "Retina Disease"]
        print(arr)
        plt.title(titles[i])
        plt.pie(arr, labels=labels)


plot_pie_sets([y_train, y_val])

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding="same", input_shape=[256, 256, 3]),
    MaxPooling2D(),
    Conv2D(64, (2, 2), padding="same", activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (2, 2), padding="same", activation='relu'),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
def convertPreds(y_pred):
    res_y_pred=[]
    for i in range(y_pred):
        res_y_pred.append(y_pred[i].argmax())
    return res_y_pred

# %%
# Define a StratifiedKFold object
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Iterate over the K folds
for train_index, test_index in skf.split(X_train, y_train):
    # Split the data into K folds
    X_fold_train, X_fold_test = X_train[train_index], X_train[test_index]
    y_fold_train, y_fold_test = y_train[train_index], y_train[test_index]

    # Train and evaluate the model on the fold
    model.fit(X_fold_train, y_fold_train,validation_data=(X_fold_test,y_fold_test),epochs=10)

# %%
# Evaluate the model on the test set
y_pred = convertPreds(model.predict(x_val))
accuracy = accuracy_score(y_val, y_pred)
print(f'Test set accuracy: {accuracy:.2f}')

# %% [markdown]
# history_vanilla = model.fit(X_train, y_train.flatten(), batch_size=BATCH_SIZE, epochs=EPOCHS,
#                             validation_data=(x_val, y_val.flatten()))

# %%
def plot_history(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %% [markdown]
# plot_history(history_vanilla)

# %%
[X_train, x_val, y_train, y_val] = create_dataset(df, 1)
